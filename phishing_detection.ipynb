# %%
import pandas as pd

# %%
data = {
    "url_length": [75, 48, 22, 90, 35, 60],
    "has_https": [0, 1, 1, 0, 1, 0],
    "has_at": [1, 0, 0, 1, 0, 1],
    "has_hyphen": [1, 0, 0, 1, 0, 1],
    "label": [1, 0, 0, 1, 0, 1]
}

df = pd.DataFrame(data)
df
# Out:
#    url_length  has_https  has_at  has_hyphen  label
# 0          75          0       1           1      1
# 1          48          1       0           0      0
# 2          22          1       0           0      0
# 3          90          0       1           1      1
# 4          35          1       0           0      0
# 5          60          0       1           1      1

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

X = df.drop("label", axis=1)
y = df["label"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

model = LogisticRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.5

# %%
import pandas as pd

test_url = pd.DataFrame(
    [[85, 0, 1, 1]],
    columns=["url_length", "has_https", "has_at", "has_hyphen"]
)

model.predict(test_url)
# Out:
# array([1])

# %%
test_url2 = pd.DataFrame(
    [[30, 1, 0, 0]],
    columns=["url_length", "has_https", "has_at", "has_hyphen"]
)

model.predict(test_url2)
# Out:
# array([0])
